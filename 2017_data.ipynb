# %% [markdown]
# Import libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
nflx_stocks = pd.read_csv("NFLX.csv")

# %%
print(nflx_stocks.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
dowjones = pd.read_csv("DJI.csv")

# %%
print(dowjones.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#       Adj Close      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000
# 2  20663.220703  6941970000
# 3  20940.509766  5392630000
# 4  21008.650391  6613570000

# %%
netflx_quarterly_stocks = pd.read_csv("NFLX_daily_by_quarter.csv")

# %%
print(netflx_quarterly_stocks.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1

# %%
nflx_stocks.rename(columns={'Adj Close':'Price'}, inplace=True)

# %%
netflx_quarterly_stocks.rename(columns={'Adj Close':'Price'}, inplace=True)
print(netflx_quarterly_stocks.head())
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1

# %%
dowjones.rename(columns = {'Adj Close':'Price'}, inplace=True)
print(dowjones.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#           Price      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000
# 2  20663.220703  6941970000
# 3  20940.509766  5392630000
# 4  21008.650391  6613570000

# %%
nflx_stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
ax = sns.violinplot(x='Quarter', y='Price', data=netflx_quarterly_stocks)
ax.set_title("Distribution of Netflix Prices by Quarter for 2017")
ax.set_ylabel("Closing Stock Price")
ax.set_xlabel("Business Quarters in 2017")
plt.show()
plt.close()

# %%
x_position = [1,2,3,4]
chart_labels = ["1Q2017","2Q2017","3Q2017","4Q2017"]
earnings_actual =[.4, .15, .29, .41]
earnings_estimate = [.37, .15, .32, .41]

# %%
fig, ax = plt.subplots()
plt.scatter(x_position, earnings_actual, color='red', alpha=0.5)
plt.scatter(x_position, earnings_estimate, color='blue', alpha=0.5)
plt.legend(["Actual", "Estimate"])
plt.xticks(x_position, chart_labels)
plt.title('Earnings Per Share in Cents')

plt.show()
plt.close()
plt.savefig("earnings.png")

# %%
quarterly_revenue = [2.79, 2.98, 3.29, 3.7]
quarterly_earnings = [.0656,.12959,.18552,.29012]
quarterly_labels = ["2Q","3Q","4Q","1Q"]

# %%
import numpy as np
indx = np.arange(len(quarterly_labels))

# Set a value for bar width.
bar_width = 0.35

# Create a subplot 
fig, ax = plt.subplots()
revenue_bar = ax.bar(indx - bar_width/2, quarterly_revenue, bar_width, label='Revenue')
earnings_bar = ax.bar(indx + bar_width/2, quarterly_earnings, bar_width, label='Earnings')
ax.set_xticks(indx)
ax.set_xticklabels(quarterly_labels)
# Out:
# [Text(0, 0, '2Q'), Text(1, 0, '3Q'), Text(2, 0, '4Q'), Text(3, 0, '1Q')]

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 12), dpi=80)
ax1 = plt.subplot(1, 2, 1)
plt.plot(nflx_stocks['Date'], nflx_stocks['Price'])
plt.title("Netflix", fontsize=24)
plt.ylabel("Stock Price", fontsize=24)
plt.xlabel("Date", fontsize=24)
# plt.tick_params(left=True,
#                 bottom=False,
#                 labelleft=True,
#                 labelbottom=False)
plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=45)

# Right plot Dow Jones
ax2 = plt.subplot(1, 2, 2)
plt.plot(dowjones['Date'], dowjones['Price'])
plt.title("Dow Jones", fontsize=24)
plt.ylabel("Stock Price", fontsize=24)
plt.xlabel("Date", fontsize=24)
# plt.tick_params(left=True,
#                 bottom=True,
#                 labelleft=True,
#                 labelbottom=True)

plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=45)

#plt.tight_layout()
plt.show()
plt.savefig("stockprice.png")

# %%
plt.savefig("")

# %%
plt.savefig("2017_data.png")

# %%
nflx_stocks['Date'] = pd.to_datetime(nflx_stocks['Date'])
dowjones['Date'] = pd.to_datetime(dowjones['Date'])
plt.tight_layout()
plt.subplots_adjust(wspace=.5)
plt.show()
plt.close()
